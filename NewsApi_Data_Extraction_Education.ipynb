# %%
from newsapi import NewsApiClient
import datetime as dt
import pandas as pd

# %%
key = "3d9325bb60a94ecfb4ea1fe168a2bea7"
newsapi = NewsApiClient(api_key=key)

# %%
data = newsapi.get_everything(q='Education', language='en', page_size=20)

# %%
data.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
data["totalResults"]
# Out:
# 43432

# %%
articles = data["articles"]

# %%
df = pd.DataFrame(articles)

# %%
df
# Out:
#                                                source  \
# 0          {'id': 'techcrunch', 'name': 'TechCrunch'}
# 1          {'id': 'techcrunch', 'name': 'TechCrunch'}
# 2                    {'id': 'wired', 'name': 'Wired'}
# 3          {'id': 'techcrunch', 'name': 'TechCrunch'}
# 4                 {'id': None, 'name': 'Gizmodo.com'}
# 5   {'id': 'the-new-york-times', 'name': 'The New ...
# 6          {'id': 'techcrunch', 'name': 'TechCrunch'}
# 7          {'id': 'techcrunch', 'name': 'TechCrunch'}
# 8          {'id': 'techcrunch', 'name': 'TechCrunch'}
# 9          {'id': 'techcrunch', 'name': 'TechCrunch'}
# 10             {'id': 'mashable', 'name': 'Mashable'}
# 11  {'id': 'the-new-york-times', 'name': 'The New ...
# 12                       {'id': 'cnn', 'name': 'CNN'}
# 13         {'id': 'techcrunch', 'name': 'TechCrunch'}
# 14                    {'id': None, 'name': 'Hbr.org'}
# 15         {'id': 'techcrunch', 'name': 'TechCrunch'}
# ...

# %%
df.to_csv('education.csv',index=True)
