# %%
from newsapi import NewsApiClient
import datetime as dt
import pandas as pd

# %%
key = "3d9325bb60a94ecfb4ea1fe168a2bea7"
newsapi = NewsApiClient(api_key=key)

# %%
data = newsapi.get_everything(q='Dalhousie University', language='en', page_size=20)

# %%
data.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
data["totalResults"]
# Out:
# 217

# %%
articles = data["articles"]

# %%
df = pd.DataFrame(articles)

# %%
df
# Out:
#                                                source  \
# 0             {'id': None, 'name': 'Halifaxtoday.ca'}
# 1             {'id': None, 'name': 'Mississauga.com'}
# 2             {'id': None, 'name': 'Thetelegram.com'}
# 3          {'id': None, 'name': 'Runningmagazine.ca'}
# 4                {'id': None, 'name': 'Castanet.net'}
# 5               {'id': None, 'name': 'Globalnews.ca'}
# 6             {'id': None, 'name': 'Jordantimes.com'}
# 7                  {'id': None, 'name': 'Bustle.com'}
# 8            {'id': None, 'name': 'Sciencedaily.com'}
# 9          {'id': None, 'name': 'Everydayhealth.com'}
# 10           {'id': 'usa-today', 'name': 'USA Today'}
# 11              {'id': None, 'name': 'Globalnews.ca'}
# 12        {'id': None, 'name': 'Electricautonomy.ca'}
# 13               {'id': None, 'name': 'Futurity.org'}
# 14                   {'id': None, 'name': 'Nejm.org'}
# 15                  {'id': None, 'name': 'Yahoo.com'}
# ...

# %%
df.to_csv("dalhousie_university.csv", index=True)
