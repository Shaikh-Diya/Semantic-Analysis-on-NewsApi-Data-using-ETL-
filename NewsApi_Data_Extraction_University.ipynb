# %%
from newsapi import NewsApiClient
import datetime as dt
import pandas as pd

# %%
key = "3d9325bb60a94ecfb4ea1fe168a2bea7"
newsapi = NewsApiClient(api_key=key)

# %%
data = newsapi.get_everything(q='University', language='en', page_size=20)

# %%
data.keys()
# Out:
# dict_keys(['status', 'totalResults', 'articles'])

# %%
data["totalResults"]
# Out:
# 239

# %%
articles = data["articles"]

# %%
df = pd.DataFrame(articles)

# %%
df
# Out:
#                                                source  \
# 0             {'id': None, 'name': 'Halifaxtoday.ca'}
# 1             {'id': None, 'name': 'Mississauga.com'}
# 2             {'id': None, 'name': 'Thetelegram.com'}
# 3          {'id': None, 'name': 'Runningmagazine.ca'}
# 4                {'id': None, 'name': 'Castanet.net'}
# 5            {'id': None, 'name': 'Sciencedaily.com'}
# 6               {'id': None, 'name': 'Globalnews.ca'}
# 7   {'id': 'the-globe-and-mail', 'name': 'The Glob...
# 8             {'id': None, 'name': 'Jordantimes.com'}
# 9                  {'id': None, 'name': 'Bustle.com'}
# 10        {'id': None, 'name': 'Electricautonomy.ca'}
# 11         {'id': None, 'name': 'Everydayhealth.com'}
# 12  {'id': 'the-globe-and-mail', 'name': 'The Glob...
# 13           {'id': 'usa-today', 'name': 'USA Today'}
# 14               {'id': None, 'name': 'Hackaday.com'}
# 15                 {'id': None, 'name': 'Forbes.com'}
# 16                   {'id': None, 'name': 'Nejm.org'}
# 17                  {'id': None, 'name': 'Yahoo.com'}
# 18              {'id': None, 'name': 'Globalnews.ca'}
# 19  {'id': 'al-jazeera-english', 'name': 'Al Jazee...
#
#                                                author  \
# 0                                    The Conversation
# 1                                                None
# 2                                       Sharon Kirkey
# 3                                    Canadian Running
# 4                                                None
# 5                                                None
# 6                                   Michelle McQuigge
# 7                                                None
# 8                                                None
# 9                                                None
# 10                                       Emma Jarratt
# 11                                        Becky Upham
# 12                                               None
# 13               USA TODAY, Ryan W. Miller, USA TODAY
# 14                                       Bob Baddeley
# 15  Sandra MacGregor, Contributor, Sandra MacGrego...
# 16  Jon Dorling, Jane Abbott, Janet Berrington, Be...
# 17                                     Laurent Belsie
# 18                                      Rachel Browne
# 19                                         Al Jazeera
#
#                                                 title  \
# 0   Decision to deploy genetically modified mosqui...
# 1   Scientist faces criticism on red meat study - ...
# 2   No, beef isn't bad for you: Scientists conclud...
# 3   Red meat: study shows the danger may be less t...
# 4   Study: red meat not so bad? - Canada News - Ca...
# 5   No need to cut down red and processed meat: Study
# 6   Experts say zero-tolerance policies aimed at s...
# 7   To meat, or not to meat: Here's how good or ba...
# 8     Should you keep eating red meat? - Jordan Times
# 9   A New Study Says Red Meat Isn't Bad For You — ...
